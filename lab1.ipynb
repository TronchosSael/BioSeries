# %%
import numpy as np

# %% [markdown]
# a) Cree el siguiente par de vectores:
#
# a = [3.1,1, -0.5, -3.2, 6], b= [1, 3, 2.2, 5.1, 1]

# %% [markdown]
# Se construyen los dos vectores como array de numpy

# %%
a = np.array([3.1, 1, -0.5, -3.2, 6])
b = np.array([1, 3, 2.2, 5.1, 1])
print("\nVector a:")
print(a)
print("\nVector b:")
print(b)
# Out:
# Vector a:
# [ 3.1  1.  -0.5 -3.2  6. ]
#
# Vector b:
# [1.  3.  2.2 5.1 1. ]

# %% [markdown]
# b) Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar los dos vectores?

# %% [markdown]
# multiplicacion escalar de los dos vectores a,b

# %%
c = np.dot(a,b)
print("\nVector c (multiplicacion escalar):")
print(c)
# Out:
# Vector c (multiplicacion escalar):
# -5.32

# %% [markdown]
# c) Implemente la multiplicación punto a punto de a.b.

# %% [markdown]
# producto punto a punto entre los dos vectores

# %%
d = a*b
print("\nVector d (multiplicacion punto a punto):")
print(d)
# Out:
# Vector d (multiplicacion punto a punto):
# [  3.1    3.    -1.1  -16.32   6.  ]

# %% [markdown]
# d) Construya la siguiente matriz: 𝐴=[2−1−3 41.5−2.57.3−0.90.2]

# %% [markdown]
# Construccion de la matriz como un array de numpy

# %%
A = np.array([[2, -1, -3], [4, 1.5, -2.5], [7.3, -0.9, 0.2]])
print("\nMatriz A:")
print(A)
# Out:
# Matriz A:
# [[ 2.  -1.  -3. ]
#  [ 4.   1.5 -2.5]
#  [ 7.3 -0.9  0.2]]

# %% [markdown]
# e) Obtenga su transpuesta AT

# %% [markdown]
# Transpuesta de la matriz A desde propiedad de objeto array numpy

# %%
AT = A.T
print("\nMatriz A transpuesta:")
print(AT)
# Out:
# Matriz A transpuesta:
# [[ 2.   4.   7.3]
#  [-1.   1.5 -0.9]
#  [-3.  -2.5  0.2]]

# %% [markdown]
# f) Consulte la función de los siguientes comandos de la librería numpy: ones, round, ceil, floor, implemente cada función para ejemplificar su uso.

# %%
### numpy.ones(shape): Crea una nueva matriz de la forma especificada, llena de unos.

unos = np.ones((3, 3))
print("\nMatriz de unos:")
print(unos)

### numpy.round(a, decimals): Redondea los elementos de la matriz a al número de decimales especificado.

r_A = np.round(A, 1)
print("\nMatriz A redondeada a 1 decimal:")
print(r_A)

### numpy.ceil(x): Redondea los elementos de x al entero más cercano hacia arriba.

up_A = np.ceil(A)
print("\nEntero superiror de la matriz A:")
print(up_A)


###numpy.floor(x): Redondea los elementos de x al entero más cercano hacia abajo.

dwn_A = np.floor(A)
print("\nEntero inferior de la matriz A:")
print(dwn_A)
# Out:
# Matriz de unos:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]
#
# Matriz A redondeada a 1 decimal:
# [[ 2.  -1.  -3. ]
#  [ 4.   1.5 -2.5]
#  [ 7.3 -0.9  0.2]]
#
# Entero superiror de la matriz A:
# [[ 2. -1. -3.]
#  [ 4.  2. -2.]
#  [ 8. -0.  1.]]
#
# Entero inferior de la matriz A:
# [[ 2. -1. -3.]
#  [ 4.  1. -3.]
#  [ 7. -1.  0.]]

# %% [markdown]
# g) Acceda al valor de la primera fila, tercera columna de la matriz A, imprímalo en consola.

# %%
valor = A[0, 2]
print(f"El valor de la primera fila, tercera columna de la matriz A es: {valor}")
# Out:
# El valor de la primera fila, tercera columna de la matriz A es: -3.0

# %% [markdown]
# h) Obtenga la segunda fila de dicha matriz, imprímalo en consola.

# %%
segunda_fila = A[1, :]
print(f"La segunda fila de la matriz A es: {segunda_fila}")
# Out:
# La segunda fila de la matriz A es: [ 4.   1.5 -2.5]

# %% [markdown]
# i) Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz A e imprímalo en consola.

# %%
dimensiones = A.shape
print(f"Las dimensiones de la matriz A son: {dimensiones}")
# Out:
# Las dimensiones de la matriz A son: (3, 3)

# %% [markdown]
# j) Construya la función 𝑦[𝑛]=sin⁡(𝜋∗0.12𝑛) en el intervalo 0 <= n <= 100.

# %%
n = np.arange(0, 101, 1)
y = np.sin(np.pi * 0.12 * n)

# %% [markdown]
# k) Construya otra senoidal 𝑦2[𝑛]=cos(2𝜋∗0.03𝑛)

# %%
y2 = np.cos(2 * np.pi * 0.03 * n)

# %% [markdown]
# l) Genere una tercera señal que sea la suma de estas dos señales, es decir 𝑠[𝑛]=y[n]+𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛]=y[n].𝑦2[𝑛].

# %%
s = y + y2
t = y * y2

# %% [markdown]
# m) Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.plot(n, y, label='y[n] = sin(π*0.12n)', color='blue')
plt.plot(n, y2, label='y2[n] = cos(2π*0.03n)', color='red')
plt.xlabel('n')
plt.ylabel('Amplitud')
plt.title('Señales y[n] y y2[n]')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# n) Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
plt.figure(figsize=(12, 6))
plt.plot(n, s, label='s[n] = y[n] + y2[n]', color='green')
plt.plot(n, t, label='t[n] = y[n] * y2[n]', color='purple')
plt.xlabel('n')
plt.ylabel('Amplitud')
plt.title('Señales s[n] y t[n]')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ¡RETO!
#
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.

# %%
def stats_notas(notas):
    # Convertir el diccionario de notas a una lista
    notas_lista = list(notas.values())

    # Calcular estadísticas
    minima = np.min(notas_lista)
    maxima = np.max(notas_lista)
    media = np.mean(notas_lista)
    desviacion = np.std(notas_lista)

    # Devolver las estadísticas como una serie
    return {'Mínima': minima, 'Máxima': maxima, 'Media': media, 'Desviación Típica': desviacion}

# Ejemplo
notas = {'Daniel': 7.3, 'Juliana': 6.9, 'Carlos': 6.4, 'Daniela': 8.2, 'David': 9.5}
print(stats_notas(notas))
# Out:
# {'Mínima': 6.4, 'Máxima': 9.5, 'Media': 7.659999999999999, 'Desviación Típica': 1.0928860873851398}
